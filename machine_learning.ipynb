# %% [markdown]
# # Machine Learning
# ## Compulsory task

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      |                Input(s)                        |                Output                               |
# | ---- | ---------------------------------------------- | --------------------------------------------------- |
# | 1.1  | Sensor data from camera LIDAR,radar,and GPS    | Steering angle adjustment                           |
# | 1.2  | Time spent watching different types of content | List of recommended movies and TV                   |
# | 1.3  | Image or scanned copy of a signature           | Verification result                                 |
# | 1.4  | Results from diagnostic tests                  | Diagnosis of a condition or disease                 |
#
# Justifications:
# 1.1 Self-Driving Car
# > A self-driving car needs to interpret a vast array of sensory data to make real-time driving decision
#
# 1.2 Netflix recommendation system
# > Netflix uses user data to tailor recommendations.By analyzing past behavior and preferences, the system predicts what the user might enjoy watching next, thereby improving user engagement and satisfaction.
#
# 1.3 Signature Recognition
# > Signature recognition systems compare the input signature with stored templates or known signatures.
#
# 1.4 Medical Diagnosis
# > Medical diagnosis systems analyze various types of patient data to identify potential health issues.

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata.
# * 2.2 Forecasting the stock price of a company based on historical data and market trends.
# * 2.3 Sorting images of animals into different species based on their visual features.
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results.

# %% [markdown]
# 2. Answer here
# * 2.1 Classfication
# > This problem involves assigning each email to one of the predifined categories promotion or social.
#
# * 2.2 Regression
# > Forecasting stock prices involves predicting a continuous the future stock price.
#
# * 2.3 Classification
# > Sorting images of animals into different species involves assigning each image to specific species.
#
# * 2.4 Classfication
# > Predicting whether a patient has a particular disease is a classification problem. The outcome is a categorical variable, making classification algorithms suitable for this type of medical diagnosis task.

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
# * 3.1 Unsupervised
# > When there is no prior knowledge of specific anomaly patterns, unsupervised learning is suitable because it can identify outliers or unusual patterns in the data without labeled examples
#
# * 3.2 Supervised
# > Predicting customer lifetime value involves using historical data(transitions and demographics) to predict a specific outcome(the future value a costumer will bring)
#
# * 3.3 Unsupervised
# > Segmenting customers into groups based on their behaviors and preferences is an unsupervised learning problem because it involves finding inherent structures or patterns in the data without predefined labels.
#
# * 3.4 Supervised
# > Categorizing social media posts into predefined themes is a supervised learning task because it involves assigning labels to new data based on training data where the categories are known.

# %% [markdown]
# 4.
# For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# *4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
# * 4.1 No, supervised learning is more appropriate
# > If most transactions are already labeled as fraudulent or legitimate, supervised learning is generally suffient. Semi-supervised learning is typically used when only a small portion of the data is labeled.
#
# * 4.2 Yes, semi-supervised learning is appropriate
# > Semi-supervised learning is well-suited for scenarios where only a small portion of the data is labeled. In this case, the algorithm can leverage the large amount of unlabeled data alongside the labeled portion to improve model performance.
#
# * 4.3 No, supervised learning is more appropriate
# > With the majority of emails already labeled, a supervised learning approach is usually more effictive. Semi-supervised learning is more  beneficial when labeled data is scarce.
#
# * 4.4 No, supervised learning is more appropriate
# > If the dataset contains complete financial and credit-related information with labels indicating whether past applicants defaulted or not, supervised learning is suitable. Since the problem involves predicting a specific outcomes(probability of default) based on well-labeled data, supervised algorithms can effictively learn from these labels to make  accurate predictions for new applicants.
